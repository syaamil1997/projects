# %% [markdown]
# https://www.kaggle.com/namanmanchanda/heart-attack-eda-prediction-90-accuracy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **Data Intro Basic**

# %%
data = pd.read_csv("singapore_airbnb.csv")

# %%
data.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7907 entries, 0 to 7906
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7907 non-null   int64
#  1   name                            7905 non-null   object
#  2   host_id                         7907 non-null   int64
#  3   host_name                       7907 non-null   object
#  4   neighbourhood_group             7907 non-null   object
#  5   neighbourhood                   7907 non-null   object
#  6   latitude                        7907 non-null   float64
#  7   longitude                       7907 non-null   float64
#  8   room_type                       7907 non-null   object
#  9   price                           7907 non-null   int64
#  10  minimum_nights                  7907 non-null   int64
#  11  number_of_reviews               7907 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
#isnull check
data.isnull()
# Out:
#          id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 7906  False  False    False      False                False          False
# 5627  False  False    False      False                False          False
# 5626  False  False    False      False                False          False
# 5625  False  False    False      False                False          False
# 2125  False  False    False      False                False          False
# ...     ...    ...      ...        ...                  ...            ...
# 722   False  False    False      False                False          False
# 470   False  False    False      False                False          False
# 1237  False  False    False      False                False          False
# 140   False  False    False      False                False          False
# 132   False  False    False      False                False          False
#
#       latitude  longitude  room_type  price  minimum_nights  \
# ...

# %%
#isnull check by column
#if false means that theres no null values in the columns
data.isnull().any()
# Out:
# id                                False
# name                               True
# host_id                           False
# host_name                         False
# neighbourhood_group               False
# neighbourhood                     False
# latitude                          False
# longitude                         False
# room_type                         False
# price                             False
# minimum_nights                    False
# number_of_reviews                 False
# last_review                        True
# reviews_per_month                  True
# calculated_host_listings_count    False
# availability_365                  False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# id                                   0
# name                                 2
# host_id                              0
# host_name                            0
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2758
# reviews_per_month                 2758
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
data.describe()
# Out:
#                  id       host_id     latitude    longitude         price  \
# count  7.907000e+03  7.907000e+03  7907.000000  7907.000000   7907.000000
# mean   2.338862e+07  9.114481e+07     1.314192   103.848787    169.332996
# std    1.016416e+07  8.190910e+07     0.030577     0.043675    340.187599
# min    4.909100e+04  2.366600e+04     1.243870   103.646560      0.000000
# 25%    1.582180e+07  2.305808e+07     1.295795   103.835825     65.000000
# 50%    2.470627e+07  6.344891e+07     1.311030   103.849410    124.000000
# 75%    3.234850e+07  1.553811e+08     1.322110   103.872535    199.000000
# max    3.811276e+07  2.885676e+08     1.454590   103.973420  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count     7907.000000        7907.000000        5149.000000
# mean        17.510054          12.807386           1.043669
# std         42.094616          29.707746           1.285851
# ...

# %%
#finding the host that has the most registered room
data['host_name'].unique
# Out:
# <bound method Series.unique of 0       Francesca
# 1         Sujatha
# 2       Francesca
# 3         Belinda
# 4         Belinda
#           ...
# 7902        Belle
# 7903         Neha
# 7904        Mindy
# 7905        Huang
# 7906      Terence
# Name: host_name, Length: 7907, dtype: object>

# %%
new_list = [item for item in data['host_name']]

# %%
unique_owners = list(set(new_list))

# %%
#count repetition for every unique owners

# %%
#count repetition for every unique owners
my_dict = {i:new_list.count(i) for i in new_list}
my_dict
# Out:
# {'Francesca': 2,
#  'Sujatha': 1,
#  'Belinda': 9,
#  'Bianca': 4,
#  'K2 Guesthouse': 32,
#  'Elizabeth': 10,
#  'Aresha': 1,
#  'Adi': 1,
#  'Susan': 1,
#  'Lena': 3,
#  'Frederic': 1,
#  'Roger': 3,
#  'Grace': 11,
#  'Audrey': 10,
#  'Shirlnet': 1,
#  'Jimm': 1,
#  'Richard': 7,
#  'Christiana': 1,
#  'Sharon': 21,
#  'Homestay In Central Singapore': 1,
#  'Kaurus': 112,
#  'Immellymel': 1,
#  'Jenny': 17,
#  'Dara': 1,
#  'Sue / Mylene': 3,
#  'Tania': 2,
#  'Laura': 6,
#  'F': 3,
#  'Gin': 1,
#  'Linton': 1,
#  'Jill': 1,
#  'Joyce': 23,
#  'Natesh': 2,
#  'Yuan': 5,
#  'Martin': 7,
#  'Sarah': 15,
#  'Lydia': 7,
#  'Su': 5,
#  'Quinn': 4,
#  'Catherine': 30,
#  'Sheryl': 2,
#  'Caleb': 9,
#  'Ruth Mandy': 11,
#  'Charlyn': 1,
#  'Sophie': 17,
#  'Joel': 4,
#  'James': 40,
#  'Jack': 4,
#  'Domus': 1,
#  'Gerard': 1,
#  'Ben': 48,
#  'Betty': 11,
#  'Soh': 1,
#  'Serene': 3,
#  'Takico': 2,
#  'Superb Hostel': 7,
#  'Coco': 4,
#  'Wink': 5,
#  'Joey': 94,
#  'Jim': 4,
# ...

# %%
sorted_host_values = sorted(my_dict.items(),key=lambda x:x[1],reverse=True)
sorted_host_values

# %%
sorted_host_values = sorted(my_dict.items(),key=lambda x:x[1],reverse=True)
sorted_host_values
# Out:
# [('Jay', 290),
#  ('Alvin', 249),
#  ('Richards', 157),
#  ('Aaron', 145),
#  ('Rain', 115),
#  ('Darcy', 114),
#  ('Kaurus', 112),
#  ('RedDoorz', 109),
#  ('Alex', 105),
#  ('Joey', 94),
#  ('Xiaoyu', 79),
#  ('Rajan', 78),
#  ('Paridhi', 76),
#  ('Shirley', 68),
#  ('Apollo', 67),
#  ('Marcelo', 67),
#  ('Paryani', 64),
#  ('Chelsey', 59),
#  ('Hillary', 49),
#  ('Ben', 48),
#  ('Rc', 48),
#  ('Vinn', 45),
#  ('Jhian', 45),
#  ('River City Inn', 43),
#  ('Expats Housing Provider @ Raffles P', 41),
#  ('James', 40),
#  ('Heritage Apartments', 40),
#  ('Jimmy', 39),
#  ('Tom', 37),
#  ('Yee', 36),
#  ('Lee', 35),
#  ('Ong', 35),
#  ('Neha', 34),
#  ('Kevin', 33),
#  ('Belle', 33),
#  ('K2 Guesthouse', 32),
#  ('Mike', 32),
#  ('Linda', 32),
#  ('Ada', 32),
#  ('Katherine', 31),
#  ('Catherine', 30),
#  ('Chris', 30),
#  ('Mindy', 29),
#  ('Lucy', 28),
#  ('L', 28),
#  ('Seven', 28),
#  ('Kay', 28),
#  ('Anna', 27),
#  ('Su Moy', 27),
#  ('David', 26),
#  ('Amy', 26),
# ...

# %%
top_5_hosts_bycount = sorted_host_values[:5]

# %%
count = 0
for item in top_5_hosts_bycount:
    count += item[1]
    
print(count)
# Out:
# 956

# %%
#total number of host
len(my_dict)
# Out:
# 1833

# %%
#total number of rented_spaces
len(new_list)
# Out:
# 7907

# %%
#the top 5 host owns for about 12% of the total rented_spaces
956/len(new_list)*100
# Out:
# 12.090552674845075

# %% [markdown]
# USING .VALUECOUNT

# %%
data['host_name'].value_counts()
# Out:
# Jay         290
# Alvin       249
# Richards    157
# Aaron       145
# Rain        115
#            ...
# King          1
# Jue           1
# 욱             1
# Ke            1
# Jowee         1
# Name: host_name, Length: 1833, dtype: int64

# %% [markdown]
# FIND THE MOST FAMOUS RENTED_SPACE AIR BNB

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
#most commonly reviewed space

# %%
data[data['number_of_reviews'] == 323]
# Out:
#           id                              name  host_id host_name  \
# 132  2129215  Luxuriously Spacious Studio Apt.  7642747   Shirley
#
#     neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 132         East Region         Bedok   1.32122  103.91492  Entire home/apt
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 132    139               2                323  2019-08-22               4.72
#
#      calculated_host_listings_count  availability_365
# 132                               1               239

# %%
data['number_of_reviews'].unique
# Out:
# <bound method Series.unique of 7906      0
# 5627      0
# 5626      0
# 5625      0
# 2125      0
#        ...
# 722     291
# 470     296
# 1237    296
# 140     307
# 132     323
# Name: number_of_reviews, Length: 7907, dtype: int64>

# %% [markdown]
# ^based on this, we know that the highest amount of reviews is 245 which is owned by 'The Antiquity Room'

# %%
data[data['host_name'] =='Eddie']
# Out:
#             id                                     name   host_id host_name  \
# 4716  28571914  Brand new contemporary apartment rental  43543631     Eddie
# 2322  17483524       Brand new contemporary room rental  43543631     Eddie
# 3317  21915252                             The Obi Room  30080617     Eddie
# 465    5798211                         The Studio Suite  30080617     Eddie
# 829    8180346                             The Zen Room  30080617     Eddie
# 489    5919270                       The Antiquity Room  30080617     Eddie
# 517    6147142                           The Music Room  30080617     Eddie
# 469    5827713                    The Private Sanctuary  30080617     Eddie
# 470    5827998                            The Lily Room  30080617     Eddie
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 4716      Central Region        Rochor   1.30261  103.84900  Entire home/apt
# ...

# %% [markdown]
# assuming the number of reviews = popularity.
# my question is, is there any correlation between location and popularity

# %%
data['host_name'].value_counts()
# Out:
# Jay         290
# Alvin       249
# Richards    157
# Aaron       145
# Rain        115
#            ...
# King          1
# Jue           1
# 욱             1
# Ke            1
# Jowee         1
# Name: host_name, Length: 1833, dtype: int64

# %%
data[data['host_name'] == 'Jay']
# Out:
#             id                                               name   host_id  \
# 5612  31241309   Inviting & Cozy 2BR APT 3 mins from Tg Pagar MRT  66406177
# 5589  31156539  Pleasant & Comfy Studio APT near Potong Pasir MRT  66406177
# 5631  31296502    Gem of the West 1BR APT 3mins from Jurong E MRT  66406177
# 5652  31364014   Gem of the west 2BR Apt 3 mins from Jurong E MRT  66406177
# 5636  31297928            Idyllic & Cosy 2BR Apartment in Orchard  66406177
# ...        ...                                                ...       ...
# 714    7537301               Ocean view  Master Room in Penthouse  10064384
# 2701  19380133         Superhost 2BR APT 3 mins from Tg Pagar MRT  66406177
# 942    8909347             Super Big Penthouse - Master room S2-3  10064384
# 709    7517671                              Super Big Master room  10064384
# 943    8909399                         Penthouse Master Room S2-4  10064384
#
# ...

# %%
len(data)
# Out:
# 7907

# %%
data19 = data[data['last_review'] > '2019-01-01']

# %%
round(len(data19)/len(data)*100,2)
# Out:
# 47.01

# %%
data19
# Out:
#             id                                               name    host_id  \
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO     367042
# 4        71896                    B&B  Room 1 near Airport & EXPO     367042
# 5        71903                         Room 2-near Airport & EXPO     367042
# 6        71907                   3rd level Jumbo room 5 near EXPO     367042
# 7       241503             Long stay at The Breezy East "Leopard"    1017645
# ...        ...                                                ...        ...
# 7715  37621650  Comfortable and spacious four-bedroom family s...   43591543
# 7728  37690516           cozy Condominium in quite neighbourhoods  165475492
# 7752  37798739                      near Clementi MRT female only  157856583
# 7766  37841266      Sunny Modern Condo in City Center walk to MRT   39207304
# 7767  37852422  Private Room With King Size Bed Near Seng Kang...  119880789
#
# ...

# %%
data19.to_csv('singapore_2019_airbnb.csv')
